327\376\262\277J\240\302\374\233[\313\225y\275?\334\254|\352\323*\365\257\244\200\244$\213\264\022\000\3316r\213Rh\211!\246\0003\010\317\235\243\326\024\267\357\366\367\034\254TNCP\004g\305\310\331\304\306\021\353\367\277\216\324\036\263\2733\034\024\r\216\036\013\025\242\273@\346\031\262H\035\020\204\314\2462\356lx\217I\302\273E\222\360+_\344\014\'c{\234+b\3670LZ\201\206?\210\3327\206\333\277e\321\253\264\272>Gi\250[\032L\020\230\034_\226g\225A2 \010\205\r\224\200\364\016\314U\221nW\0210\246\351\202n\352\271\311h\027\3244\311\014c\213`I\342\366\351|\333\252[9\3231d\007\326\321\251\010\000\245\217\004\271\177\334\213\212\360d\034\225\306X\014\307?:\342\304J\214\245\217`\340b\244IG\";6^\334\237v\247V,\233\311\026\274|\315\314Q\372op\222\343\367u2\366\016\274\213\2252\037KP\354T\030; c\304\000\220\030\245\364,\242\314\211$\345\001+\325\007\207\306m\'\001\013\231\n\206\367\242\374\201\342#\252\237c\014\036}\361\207z\256\246\316\332\004A\2106v\322\327\377\331"
#       }
#     }
#   }
#   feature {
#     key: "label"
#     value {
#       int64_list {
#         value: 9
#       }
#     }
#   }
# }

# %%
# see length of dataset
print(len(list(data)))
# Out:
# 27000

# %%
# print size of each of the 10 classes
for label in labels:
    count = 0
    for raw_record in data:
        example = tf.train.Example()
        example.ParseFromString(raw_record.numpy())
        if example.features.feature['label'].int64_list.value[0] == labels.index(label):
            count += 1
    print(label, count)
# Out:
# AnnualCrop 3000
# Forest 3000
# HerbaceousVegetation 3000
# Highway 2500
# Industrial 2500
# Pasture 2000
# PermanentCrop 2500
# Residential 3000
# River 2500
# SeaLake 3000

# %%
# parse single image from tfrecord
def parse_image(example_proto):
    features = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'label': tf.io.FixedLenFeature([], tf.int64),
    }
    parsed_features = tf.io.parse_single_example(example_proto, features)
    image = tf.io.decode_jpeg(parsed_features['image'])

    label = tf.cast(parsed_features['label'], tf.int32)
    return image, label

def resize_image(image, label):
    image = tf.image.resize(image, [64, 64])
    return image, label

def normalize(image, label):
    image = tf.cast(image, tf.float32)
    image = image / 255.0
    return image, label

def split_into_batches(dataset, batch_size):
    return dataset.cache().shuffle(27000).batch(batch_size)

def split_into_train_test_validation(dataset, batch_size):
    train_size = int(0.5 * 27000)
    validation_set = int(0.3 * 27000)
    test_size = int(0.2 * 27000)
    train_dataset = dataset.take(train_size).cache().shuffle(train_size).batch(batch_size)
    validation_dataset = dataset.skip(train_size).take(validation_set).cache().shuffle(validation_set).batch(batch_size)
    test_dataset = dataset.skip(train_size).skip(validation_set).take(test_size).cache().shuffle(test_size).batch(batch_size)
    return train_dataset, validation_dataset, test_dataset


def sample_images(dataset, batch_size, num_batches=500):
    return dataset.take(num_batches*batch_size).cache().batch(batch_size)

# parse first image from data
parsed_image_dataset = data.map(parse_image)
parsed_image_dataset = parsed_image_dataset.map(resize_image)

for image, label in parsed_image_dataset.take(5):
  image_raw = image.numpy()
  print(labels[label.numpy()])
  print(image_raw.shape)
  plt.imshow(image_raw.astype('uint8'))
  plt.show()
  plt.close()
  
parsed_image_dataset = parsed_image_dataset.map(normalize)
# split into train and test

train_dataset, validation_dataset, test_dataset = split_into_train_test_validation(parsed_image_dataset, 50)
# train_dataset = sample_images(train_dataset, 50, num_batches=1000)
# validation_dataset = sample_images(validation_dataset, 50)
# test_dataset = sample_images(test_dataset, 50)
# Out:
# SeaLake
# (64, 64, 3)
# PermanentCrop
# (64, 64, 3)
# SeaLake
# (64, 64, 3)
# Industrial
# (64, 64, 3)
# Pasture
# (64, 64, 3)

# %%
# build CNN model
def build_model(number_of_conv2d_layers=2, number_of_filters=32, kernel_size=(3, 3), activation='relu', padding='same', pool_size=(2, 2), dropout=0.5, number_of_dense_layers=2, number_of_dense_nodes=128, dense_activation='relu', output_activation='softmax', loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']):
    # augment data
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(1, input_shape=(64, 64, 3)),
        tf.keras.layers.RandomZoom(height_factor=0.5, width_factor=0.5),
    ])

    # create number_of_conv2d_layers:
    conv2d_layers = []
    for i in range(number_of_conv2d_layers):
        conv2d_layers.append(tf.keras.layers.Conv2D(number_of_filters, kernel_size, activation=activation, padding=padding, input_shape=(64, 64, 3)))
        conv2d_layers.append(tf.keras.layers.MaxPooling2D(pool_size))
        conv2d_layers.append(tf.keras.layers.Dropout(dropout))

    # create dense layers in for loop
    dense_layers = []
    for i in range(number_of_dense_layers):
        dense_layers.append(tf.keras.layers.Dense(number_of_dense_nodes, activation=dense_activation))
        dense_layers.append(tf.keras.layers.Dropout(dropout))
    
    model = tf.keras.Sequential([
        # data_augmentation,
        tf.keras.Sequential(conv2d_layers),
        tf.keras.layers.Flatten(),
        tf.keras.Sequential(dense_layers),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=['accuracy'])
    return model

# create early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=5, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)

results = []
number_of_filters = 32
number_of_dense_layers = 2
# for number_of_conv2d_layers in [2, 3, 4]:
for number_of_conv2d_layers in [1]:
    # for number_of_dense_nodes in [128, 256, 512]:
    for number_of_dense_nodes in [128]:
        model = build_model(number_of_conv2d_layers=number_of_conv2d_layers, number_of_filters=number_of_filters, number_of_dense_layers=number_of_dense_layers, number_of_dense_nodes=number_of_dense_nodes)
        history = model.fit(train_dataset, epochs=50, batch_size=50, validation_data=test_dataset, callbacks=[early_stopping])
        results.append((number_of_conv2d_layers, number_of_filters, number_of_dense_layers, number_of_dense_nodes, history.history['val_accuracy'][-1]))
        model.save(f'../../models/euroSAT/{number_of_conv2d_layers}_{number_of_filters}_{number_of_dense_layers}_{number_of_dense_nodes}.h5')

# store results in dataframe
results_df = pd.DataFrame(results, columns=['number_of_conv2d_layers', 'number_of_filters', 'number_of_dense_layers', 'number_of_dense_nodes', 'val_accuracy'])
results_df.sort_values(by='val_accuracy', ascending=False, inplace=True)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Epoch 1/50
# 270/270 [==============================] - 25s 87ms/step - loss: 2.0318 - accuracy: 0.2204 - val_loss: 1.6454 - val_accuracy: 0.4165
# Epoch 2/50
# 270/270 [==============================] - 25s 93ms/step - loss: 1.6384 - accuracy: 0.3656 - val_loss: 1.4463 - val_accuracy: 0.4424
# Epoch 3/50
# 270/270 [==============================] - 26s 95ms/step - loss: 1.4841 - accuracy: 0.4261 - val_loss: 1.2667 - val_accuracy: 0.5350
# Epoch 4/50
# 270/270 [==============================] - 25s 94ms/step - loss: 1.4142 - accuracy: 0.4553 - val_loss: 1.2684 - val_accuracy: 0.5565
# Epoch 5/50
# 270/270 [==============================] - 26s 98ms/step - loss: 1.3552 - accuracy: 0.4844 - val_loss: 1.2354 - val_accuracy: 0.5335
# Epoch 6/50
# 270/270 [==============================] - 27s 100ms/step - loss: 1.3348 - accuracy: 0.4926 - val_loss: 1.1721 - val_accuracy: 0.5717
# Epoch 7/50
# 270/270 [==============================] - 25s 93ms/step - loss: 1.2703 - accuracy: 0.5214 - val_loss: 1.1748 - val_accuracy: 0.5600
# Epoch 8/50
# 270/270 [==============================] - 25s 92ms/step - loss: 1.2674 - accuracy: 0.5234 - val_loss: 1.1181 - val_accuracy: 0.5863
# Epoch 9/50
# 270/270 [==============================] - 26s 97ms/step - loss: 1.2242 - accuracy: 0.5425 - val_loss: 1.1384 - val_accuracy: 0.5669
# Epoch 10/50
# 270/270 [==============================] - 25s 92ms/step - loss: 1.2039 - accuracy: 0.5507 - val_loss: 1.1463 - val_accuracy: 0.5696
# Epoch 11/50
# 270/270 [==============================] - 25s 92ms/step - loss: 1.1883 - accuracy: 0.5591 - val_loss: 1.0851 - val_accuracy: 0.6013
# Epoch 12/50
# 270/270 [==============================] - 25s 92ms/step - loss: 1.1641 - accuracy: 0.5708 - val_loss: 1.1070 - val_accuracy: 0.5981
# Epoch 13/50
# 270/270 [==============================] - 24s 89ms/step - loss: 1.1474 - accuracy: 0.5753 - val_loss: 1.0189 - val_accuracy: 0.6428
# Epoch 14/50
# 270/270 [==============================] - 27s 101ms/step - loss: 1.1350 - accuracy: 0.5810 - val_loss: 1.0875 - val_accuracy: 0.6013
# Epoch 15/50
# 270/270 [==============================] - 25s 93ms/step - loss: 1.1134 - accuracy: 0.5902 - val_loss: 1.0606 - val_accuracy: 0.6031
# Epoch 16/50
# 270/270 [==============================] - 23s 86ms/step - loss: 1.0970 - accuracy: 0.6028 - val_loss: 1.0433 - val_accuracy: 0.6252
# Epoch 17/50
# 270/270 [==============================] - 23s 84ms/step - loss: 1.0972 - accuracy: 0.5980 - val_loss: 0.9911 - val_accuracy: 0.6389
# Epoch 18/50
# 270/270 [==============================] - 22s 81ms/step - loss: 1.1049 - accuracy: 0.5981 - val_loss: 1.0180 - val_accuracy: 0.6357

# %%
# plot 3d surface of results
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(results_df['number_of_conv2d_layers'], results_df['number_of_dense_nodes'], results_df['val_accuracy'], cmap=plt.cm.viridis)
ax.set_xlabel('number_of_conv2d_layers')
ax.set_ylabel('number_of_dense_nodes')
ax.set_zlabel('val_accuracy')
plt.show()

# %%
# plot surface of results
px.surface(x=results_df['number_of_conv2d_layers'], y=results_df['number_of_dense_nodes'], z=results_df['val_accuracy'], color=results_df['val_accuracy'], opacity=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # plot surface of results
# ----> 2 px.surface(x=results_df['number_of_conv2d_layers'], y=results_df['number_of_dense_nodes'], z=results_df['val_accuracy'], color=results_df['val_accuracy'], opacity=0.5)
#
# AttributeError: module 'plotly.express' has no attribute 'surface'

# %%
# plot accuracy and loss curves
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)

# %%
# evaluate in a confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

y_true = []
y_pred = []
images = []
for image, label in test_dataset:
    y_true.append(label)
    y_pred.append(model.predict(image))
    images.append(image)

y_true = np.concatenate(y_true)
y_pred = np.concatenate(y_pred)
image_list = np.concatenate(images)

y_pred_max = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_true, y_pred_max)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='.2f', xticklabels=labels, yticklabels=labels)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 2/2 [==============================] - 1s 54ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 40ms/step

# %%
def plot_image(i, predictions_array, true_labels, images):
  predictions_array, true_label, img = predictions_array[i], true_labels[i], images[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  
  # plt.imshow(img[...,0], cmap=plt.cm.binary)
  plt.imshow(img)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
  
  plt.xlabel("{} {:2.0f}% ({})".format(labels[predicted_label],
                                100*np.max(predictions_array),
                                labels[true_label]),
                                color=color)
# change xlabel size
  plt.rcParams['xtick.labelsize'] = 10

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)
  
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, y_pred, y_true, image_list)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, y_pred, y_true)
plt.savefig('../../reports/figures/EuroSAT/satellite_items.png')
